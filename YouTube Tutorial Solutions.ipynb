# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
ri = pd.read_csv('gapminder.csv')

# %%
ri.head()
# Out:
#        country continent  year  lifeExp  population   gdpPerCap
# 0  Afghanistan      Asia  1952   28.801     8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332     9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997    10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020    11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088    13079460  739.981106

# %%
##As time goes on, is the world population inc/dec?

# %%
ri.plot.scatter(x='year', y='population')
plt.ylim(0,0.4e9)
# Out:
# (0, 400000000.0)

# %%
#Question: As time goes on, is the world population inc/dec?
##Ans:As time goes on, world population increases

# %%
##Question: what happens to the life expectancy as time goes on?
##Answer: ???

# %%
ri.head()
# Out:
#        country continent  year  lifeExp  population   gdpPerCap
# 0  Afghanistan      Asia  1952   28.801     8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332     9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997    10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020    11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088    13079460  739.981106

# %%
ri.plot.scatter(x='year', y='lifeExp')

# %%
##Question: what happens to the life expectancy as time goes on?
##Answer: Life expectancy increases as years progress

# %%
ri.head()
# Out:
#        country continent  year  lifeExp  population   gdpPerCap
# 0  Afghanistan      Asia  1952   28.801     8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332     9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997    10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020    11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088    13079460  739.981106

# %%
ri.plot.scatter(x='gdpPerCap', y='lifeExp')
plt.xscale('log')
plt.title('Life Expectancy vs. gdp per capita')
plt.xticks([1000,10000,100000] , ['1k', '10k', '100k'])
plt.grid('True')

# %%
## Question: what happens to life expectancy as the gdpPerCAP increases?
## Answer: It increases as well (up until 40,000)

# %%
ri.head()
# Out:
#        country continent  year  lifeExp  population   gdpPerCap
# 0  Afghanistan      Asia  1952   28.801     8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332     9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997    10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020    11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088    13079460  739.981106

# %%
ri.plot.scatter(x='population', y='lifeExp')
plt.xscale('log')

# %%
##Question: What age group has the most common life expectancy?
##Answer: ??

# %%
ri.lifeExp.plot(kind='hist', bins=200)

# %%
##Question: What age group has the most common life expectancy?
##Answer: 70 to 73 years of age
